# %%
# %pip install numpy pandas matplotlib
import matplotlib
import numpy 
import pandas
from data import getChelseaData
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
chelseaData = getChelseaData()
print(chelseaData.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTGS', 'ATGS', 'HTGC', 'ATGC', 'HTP', 'ATP', 'HM1', 'HM2', 'HM3',
#        'HM4', 'HM5', 'AM1', 'AM2', 'AM3', 'AM4', 'AM5', 'MW', 'HTFormPtsStr',
#        'ATFormPtsStr', 'HTFormPts', 'ATFormPts', 'HTWinStreak3',
#        'HTWinStreak5', 'HTLossStreak3', 'HTLossStreak5', 'ATWinStreak3',
#        'ATWinStreak5', 'ATLossStreak3', 'ATLossStreak5', 'HTGD', 'ATGD',
#        'DiffPts', 'DiffFormPts'],
#       dtype='str')

# %%
drop_cols = ['ATFormPtsStr', 'HTFormPts', 'ATFormPts', 'HTWinStreak3',
       'HTWinStreak5', 'HTLossStreak3', 'HTLossStreak5', 'ATWinStreak3',
       'ATWinStreak5', 'ATLossStreak3', 'ATLossStreak5','Date','Unnamed: 0','HM1', 'HM2', 'HM3',
       'HM4', 'HM5', 'AM1', 'AM2', 'AM3', 'AM4', 'AM5','MW','HTFormPtsStr','DiffPts']
chelseaData = chelseaData.drop(drop_cols,axis = 1)

# %%
print(chelseaData.columns)
print(chelseaData.head(2))
# Out:
# Index(['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTGS', 'ATGS', 'HTGC',
#        'ATGC', 'HTP', 'ATP', 'HTGD', 'ATGD', 'DiffFormPts'],
#       dtype='str')
#     HomeTeam  AwayTeam  FTHG  FTAG FTR  HTGS  ATGS  HTGC  ATGC  HTP  ATP  \
# 1    Chelsea  West Ham     4     2   H     0     0     0     0  0.0  0.0
# 11  Bradford   Chelsea     2     0   H     0     4     1     2  0.0  1.5
#
#     HTGD  ATGD  DiffFormPts
# 1    0.0   0.0          0.0
# 11  -0.5   1.0         -1.5
